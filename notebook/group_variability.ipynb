# %%
import os
import pandas as pd
import sys
sys.path.append('/sources')
import matplotlib.pyplot as plt

from preproc import *
from dataset import load_relevant_data_subset

ROOT_PATH = '/sources/dataset/'
df = pd.read_csv(os.path.join(ROOT_PATH, 'train.csv'))

paths = df.path.values
p_ids = df.participant_id.values
s_ids = df.sequence_id.values
labels = df.sign.values

# %%
easy = ['horse', 'nose', 'bug', 'airplane', 'callonphone']
hard = ['after', 'beside', 'go', 'give', 'look']

easy_idx = []
hard_idx = []
for idx, lb in enumerate(labels):
    if lb in easy:
        easy_idx.append([idx, lb])
    elif lb in hard:
        hard_idx.append([idx, lb])

# %%
lhand_off = np.array([i for i in range(21)])
rhand_off = np.array([i + 21 for i in range(21)])
lip_off = np.array([i + 42 for i in range(40)])
lip = [
            61, 185, 40, 39, 37, 0, 267, 269, 270, 409,
            291, 146, 91, 181, 84, 17, 314, 405, 321, 375,
            78, 191, 80, 81, 82, 13, 312, 311, 310, 415,
            95, 88, 178, 87, 14, 317, 402, 318, 324, 308,
]
lhand = [i for i in range(468, 489)]
rhand = [i for i in range(522, 543)]
POSE = lhand + rhand + lip

# %% [markdown]
# ### Easy case

# %%
idx = 0
data_idx = easy_idx[idx][0]
print(easy_idx[idx][1])
fig, ax = plt.subplots()
ax.invert_yaxis()


pq_file = f'/sources/dataset/{paths[data_idx]}'
xyz = load_relevant_data_subset(pq_file)

pose = xyz[:,POSE]


ax.scatter(pose[:, lhand_off, 0], pose[:, lhand_off, 1], c=pose[:, lhand_off, 2], alpha=0.1, cmap='Blues')
ax.scatter(pose[:, rhand_off, 0], pose[:, rhand_off, 1], c=pose[:, rhand_off, 2], alpha=0.1, cmap='Reds')
ax.scatter(pose[:, lip_off, 0], pose[:, lip_off, 1], c=pose[:, lip_off, 2], alpha=0.1, cmap='viridis')
plt.show()
# Out:
# callonphone

# %%
idx = 1
data_idx = easy_idx[idx][0]
print(easy_idx[idx][1])
fig, ax = plt.subplots()
ax.invert_yaxis()


pq_file = f'/sources/dataset/{paths[data_idx]}'
xyz = load_relevant_data_subset(pq_file)

pose = xyz[:,POSE]


ax.scatter(pose[:, lhand_off, 0], pose[:, lhand_off, 1], c=pose[:, lhand_off, 2], alpha=0.1, cmap='Blues')
ax.scatter(pose[:, rhand_off, 0], pose[:, rhand_off, 1], c=pose[:, rhand_off, 2], alpha=0.1, cmap='Reds')
ax.scatter(pose[:, lip_off, 0], pose[:, lip_off, 1], c=pose[:, lip_off, 2], alpha=0.1, cmap='viridis')
plt.show()
# Out:
# bug

# %%
idx = 2
data_idx = easy_idx[idx][0]
print(easy_idx[idx][1])
fig, ax = plt.subplots()
ax.invert_yaxis()


pq_file = f'/sources/dataset/{paths[data_idx]}'
xyz = load_relevant_data_subset(pq_file)

pose = xyz[:,POSE]


ax.scatter(pose[:, lhand_off, 0], pose[:, lhand_off, 1], c=pose[:, lhand_off, 2], alpha=0.1, cmap='Blues')
ax.scatter(pose[:, rhand_off, 0], pose[:, rhand_off, 1], c=pose[:, rhand_off, 2], alpha=0.1, cmap='Reds')
ax.scatter(pose[:, lip_off, 0], pose[:, lip_off, 1], c=pose[:, lip_off, 2], alpha=0.1, cmap='viridis')
plt.show()
# Out:
# bug

# %%
idx = 3
data_idx = easy_idx[idx][0]
print(easy_idx[idx][1])
fig, ax = plt.subplots()
ax.invert_yaxis()


pq_file = f'/sources/dataset/{paths[data_idx]}'
xyz = load_relevant_data_subset(pq_file)

pose = xyz[:,POSE]


ax.scatter(pose[:, lhand_off, 0], pose[:, lhand_off, 1], c=pose[:, lhand_off, 2], alpha=0.1, cmap='Blues')
ax.scatter(pose[:, rhand_off, 0], pose[:, rhand_off, 1], c=pose[:, rhand_off, 2], alpha=0.1, cmap='Reds')
ax.scatter(pose[:, lip_off, 0], pose[:, lip_off, 1], c=pose[:, lip_off, 2], alpha=0.1, cmap='viridis')
plt.show()
# Out:
# callonphone

# %%
idx = 4
data_idx = easy_idx[idx][0]
print(easy_idx[idx][1])
fig, ax = plt.subplots()
ax.invert_yaxis()


pq_file = f'/sources/dataset/{paths[data_idx]}'
xyz = load_relevant_data_subset(pq_file)

pose = xyz[:,POSE]


ax.scatter(pose[:, lhand_off, 0], pose[:, lhand_off, 1], c=pose[:, lhand_off, 2], alpha=0.1, cmap='Blues')
ax.scatter(pose[:, rhand_off, 0], pose[:, rhand_off, 1], c=pose[:, rhand_off, 2], alpha=0.1, cmap='Reds')
ax.scatter(pose[:, lip_off, 0], pose[:, lip_off, 1], c=pose[:, lip_off, 2], alpha=0.1, cmap='viridis')
plt.show()
# Out:
# bug

# %%
idx = 5
data_idx = easy_idx[idx][0]
print(easy_idx[idx][1])
fig, ax = plt.subplots()
ax.invert_yaxis()


pq_file = f'/sources/dataset/{paths[data_idx]}'
xyz = load_relevant_data_subset(pq_file)

pose = xyz[:,POSE]


ax.scatter(pose[:, lhand_off, 0], pose[:, lhand_off, 1], c=pose[:, lhand_off, 2], alpha=0.1, cmap='Blues')
ax.scatter(pose[:, rhand_off, 0], pose[:, rhand_off, 1], c=pose[:, rhand_off, 2], alpha=0.1, cmap='Reds')
ax.scatter(pose[:, lip_off, 0], pose[:, lip_off, 1], c=pose[:, lip_off, 2], alpha=0.1, cmap='viridis')
plt.show()
# Out:
# bug

# %%
idx = 6
data_idx = easy_idx[idx][0]
print(easy_idx[idx][1])
fig, ax = plt.subplots()
ax.invert_yaxis()


pq_file = f'/sources/dataset/{paths[data_idx]}'
xyz = load_relevant_data_subset(pq_file)

pose = xyz[:,POSE]


ax.scatter(pose[:, lhand_off, 0], pose[:, lhand_off, 1], c=pose[:, lhand_off, 2], alpha=0.1, cmap='Blues')
ax.scatter(pose[:, rhand_off, 0], pose[:, rhand_off, 1], c=pose[:, rhand_off, 2], alpha=0.1, cmap='Reds')
ax.scatter(pose[:, lip_off, 0], pose[:, lip_off, 1], c=pose[:, lip_off, 2], alpha=0.1, cmap='viridis')
plt.show()
# Out:
# bug

# %%
idx = 7
data_idx = easy_idx[idx][0]
print(easy_idx[idx][1])
fig, ax = plt.subplots()
ax.invert_yaxis()


pq_file = f'/sources/dataset/{paths[data_idx]}'
xyz = load_relevant_data_subset(pq_file)

pose = xyz[:,POSE]


ax.scatter(pose[:, lhand_off, 0], pose[:, lhand_off, 1], c=pose[:, lhand_off, 2], alpha=0.1, cmap='Blues')
ax.scatter(pose[:, rhand_off, 0], pose[:, rhand_off, 1], c=pose[:, rhand_off, 2], alpha=0.1, cmap='Reds')
ax.scatter(pose[:, lip_off, 0], pose[:, lip_off, 1], c=pose[:, lip_off, 2], alpha=0.1, cmap='viridis')
plt.show()
# Out:
# horse

# %%
idx = 8
data_idx = easy_idx[idx][0]
print(easy_idx[idx][1])
fig, ax = plt.subplots()
ax.invert_yaxis()


pq_file = f'/sources/dataset/{paths[data_idx]}'
xyz = load_relevant_data_subset(pq_file)

pose = xyz[:,POSE]


ax.scatter(pose[:, lhand_off, 0], pose[:, lhand_off, 1], c=pose[:, lhand_off, 2], alpha=0.1, cmap='Blues')
ax.scatter(pose[:, rhand_off, 0], pose[:, rhand_off, 1], c=pose[:, rhand_off, 2], alpha=0.1, cmap='Reds')
ax.scatter(pose[:, lip_off, 0], pose[:, lip_off, 1], c=pose[:, lip_off, 2], alpha=0.1, cmap='viridis')
plt.show()
# Out:
# bug

# %%
idx = 9
data_idx = easy_idx[idx][0]
print(easy_idx[idx][1])
fig, ax = plt.subplots()
ax.invert_yaxis()


pq_file = f'/sources/dataset/{paths[data_idx]}'
xyz = load_relevant_data_subset(pq_file)

pose = xyz[:,POSE]


ax.scatter(pose[:, lhand_off, 0], pose[:, lhand_off, 1], c=pose[:, lhand_off, 2], alpha=0.1, cmap='Blues')
ax.scatter(pose[:, rhand_off, 0], pose[:, rhand_off, 1], c=pose[:, rhand_off, 2], alpha=0.1, cmap='Reds')
ax.scatter(pose[:, lip_off, 0], pose[:, lip_off, 1], c=pose[:, lip_off, 2], alpha=0.1, cmap='viridis')
plt.show()
# Out:
# callonphone

# %%
idx = 10
data_idx = easy_idx[idx][0]
print(easy_idx[idx][1])
fig, ax = plt.subplots()
ax.invert_yaxis()


pq_file = f'/sources/dataset/{paths[data_idx]}'
xyz = load_relevant_data_subset(pq_file)

pose = xyz[:,POSE]


ax.scatter(pose[:, lhand_off, 0], pose[:, lhand_off, 1], c=pose[:, lhand_off, 2], alpha=0.1, cmap='Blues')
ax.scatter(pose[:, rhand_off, 0], pose[:, rhand_off, 1], c=pose[:, rhand_off, 2], alpha=0.1, cmap='Reds')
ax.scatter(pose[:, lip_off, 0], pose[:, lip_off, 1], c=pose[:, lip_off, 2], alpha=0.1, cmap='viridis')
plt.show()
# Out:
# callonphone

# %% [markdown]
# ### Hard case

# %%
idx = 0
data_idx = hard_idx[idx][0]
print(hard_idx[idx][1])
fig, ax = plt.subplots()
ax.invert_yaxis()


pq_file = f'/sources/dataset/{paths[data_idx]}'
xyz = load_relevant_data_subset(pq_file)

pose = xyz[:,POSE]


ax.scatter(pose[:, lhand_off, 0], pose[:, lhand_off, 1], c=pose[:, lhand_off, 2], alpha=0.1, cmap='Blues')
ax.scatter(pose[:, rhand_off, 0], pose[:, rhand_off, 1], c=pose[:, rhand_off, 2], alpha=0.1, cmap='Reds')
ax.scatter(pose[:, lip_off, 0], pose[:, lip_off, 1], c=pose[:, lip_off, 2], alpha=0.1, cmap='viridis')
plt.show()
# Out:
# go

# %%
idx = 1
data_idx = hard_idx[idx][0]
print(hard_idx[idx][1])
fig, ax = plt.subplots()
ax.invert_yaxis()


pq_file = f'/sources/dataset/{paths[data_idx]}'
xyz = load_relevant_data_subset(pq_file)

pose = xyz[:,POSE]


ax.scatter(pose[:, lhand_off, 0], pose[:, lhand_off, 1], c=pose[:, lhand_off, 2], alpha=0.1, cmap='Blues')
ax.scatter(pose[:, rhand_off, 0], pose[:, rhand_off, 1], c=pose[:, rhand_off, 2], alpha=0.1, cmap='Reds')
ax.scatter(pose[:, lip_off, 0], pose[:, lip_off, 1], c=pose[:, lip_off, 2], alpha=0.1, cmap='viridis')
# Out:
# look

# %%
idx = 2
data_idx = hard_idx[idx][0]
print(hard_idx[idx][1])
fig, ax = plt.subplots()
ax.invert_yaxis()


pq_file = f'/sources/dataset/{paths[data_idx]}'
xyz = load_relevant_data_subset(pq_file)

pose = xyz[:,POSE]


ax.scatter(pose[:, lhand_off, 0], pose[:, lhand_off, 1], c=pose[:, lhand_off, 2], alpha=0.1, cmap='Blues')
ax.scatter(pose[:, rhand_off, 0], pose[:, rhand_off, 1], c=pose[:, rhand_off, 2], alpha=0.1, cmap='Reds')
ax.scatter(pose[:, lip_off, 0], pose[:, lip_off, 1], c=pose[:, lip_off, 2], alpha=0.1, cmap='viridis')
# Out:
# go

# %%
idx = 3
data_idx = hard_idx[idx][0]
print(hard_idx[idx][1])
fig, ax = plt.subplots()
ax.invert_yaxis()


pq_file = f'/sources/dataset/{paths[data_idx]}'
xyz = load_relevant_data_subset(pq_file)

pose = xyz[:,POSE]


ax.scatter(pose[:, lhand_off, 0], pose[:, lhand_off, 1], c=pose[:, lhand_off, 2], alpha=0.1, cmap='Blues')
ax.scatter(pose[:, rhand_off, 0], pose[:, rhand_off, 1], c=pose[:, rhand_off, 2], alpha=0.1, cmap='Reds')
ax.scatter(pose[:, lip_off, 0], pose[:, lip_off, 1], c=pose[:, lip_off, 2], alpha=0.1, cmap='viridis')
# Out:
# look

# %%
idx = 5
data_idx = hard_idx[idx][0]
print(hard_idx[idx][1])
fig, ax = plt.subplots()
ax.invert_yaxis()


pq_file = f'/sources/dataset/{paths[data_idx]}'
xyz = load_relevant_data_subset(pq_file)

pose = xyz[:,POSE]


ax.scatter(pose[:, lhand_off, 0], pose[:, lhand_off, 1], c=pose[:, lhand_off, 2], alpha=0.1, cmap='Blues')
ax.scatter(pose[:, rhand_off, 0], pose[:, rhand_off, 1], c=pose[:, rhand_off, 2], alpha=0.1, cmap='Reds')
ax.scatter(pose[:, lip_off, 0], pose[:, lip_off, 1], c=pose[:, lip_off, 2], alpha=0.1, cmap='viridis')
# Out:
# beside

# %%
idx = 6
data_idx = hard_idx[idx][0]
print(hard_idx[idx][1])
fig, ax = plt.subplots()
ax.invert_yaxis()


pq_file = f'/sources/dataset/{paths[data_idx]}'
xyz = load_relevant_data_subset(pq_file)

pose = xyz[:,POSE]


ax.scatter(pose[:, lhand_off, 0], pose[:, lhand_off, 1], c=pose[:, lhand_off, 2], alpha=0.1, cmap='Blues')
ax.scatter(pose[:, rhand_off, 0], pose[:, rhand_off, 1], c=pose[:, rhand_off, 2], alpha=0.1, cmap='Reds')
ax.scatter(pose[:, lip_off, 0], pose[:, lip_off, 1], c=pose[:, lip_off, 2], alpha=0.1, cmap='viridis')
# Out:
# go

# %%
idx = 7
data_idx = hard_idx[idx][0]
print(hard_idx[idx][1])
fig, ax = plt.subplots()
ax.invert_yaxis()


pq_file = f'/sources/dataset/{paths[data_idx]}'
xyz = load_relevant_data_subset(pq_file)

pose = xyz[:,POSE]


ax.scatter(pose[:, lhand_off, 0], pose[:, lhand_off, 1], c=pose[:, lhand_off, 2], alpha=0.1, cmap='Blues')
ax.scatter(pose[:, rhand_off, 0], pose[:, rhand_off, 1], c=pose[:, rhand_off, 2], alpha=0.1, cmap='Reds')
ax.scatter(pose[:, lip_off, 0], pose[:, lip_off, 1], c=pose[:, lip_off, 2], alpha=0.1, cmap='viridis')
# Out:
# give

# %%
idx = 8
data_idx = hard_idx[idx][0]
print(hard_idx[idx][1])
fig, ax = plt.subplots()
ax.invert_yaxis()


pq_file = f'/sources/dataset/{paths[data_idx]}'
xyz = load_relevant_data_subset(pq_file)

pose = xyz[:,POSE]


ax.scatter(pose[:, lhand_off, 0], pose[:, lhand_off, 1], c=pose[:, lhand_off, 2], alpha=0.1, cmap='Blues')
ax.scatter(pose[:, rhand_off, 0], pose[:, rhand_off, 1], c=pose[:, rhand_off, 2], alpha=0.1, cmap='Reds')
ax.scatter(pose[:, lip_off, 0], pose[:, lip_off, 1], c=pose[:, lip_off, 2], alpha=0.1, cmap='viridis')
# Out:
# give

# %%
idx = 9
data_idx = hard_idx[idx][0]
print(hard_idx[idx][1])
fig, ax = plt.subplots()
ax.invert_yaxis()


pq_file = f'/sources/dataset/{paths[data_idx]}'
xyz = load_relevant_data_subset(pq_file)

pose = xyz[:,POSE]


ax.scatter(pose[:, lhand_off, 0], pose[:, lhand_off, 1], c=pose[:, lhand_off, 2], alpha=0.1, cmap='Blues')
ax.scatter(pose[:, rhand_off, 0], pose[:, rhand_off, 1], c=pose[:, rhand_off, 2], alpha=0.1, cmap='Reds')
ax.scatter(pose[:, lip_off, 0], pose[:, lip_off, 1], c=pose[:, lip_off, 2], alpha=0.1, cmap='viridis')
# Out:
# beside

# %%
idx = 10
data_idx = hard_idx[idx][0]
print(hard_idx[idx][1])
fig, ax = plt.subplots()
ax.invert_yaxis()


pq_file = f'/sources/dataset/{paths[data_idx]}'
xyz = load_relevant_data_subset(pq_file)

pose = xyz[:,POSE]


ax.scatter(pose[:, lhand_off, 0], pose[:, lhand_off, 1], c=pose[:, lhand_off, 2], alpha=0.1, cmap='Blues')
ax.scatter(pose[:, rhand_off, 0], pose[:, rhand_off, 1], c=pose[:, rhand_off, 2], alpha=0.1, cmap='Reds')
ax.scatter(pose[:, lip_off, 0], pose[:, lip_off, 1], c=pose[:, lip_off, 2], alpha=0.1, cmap='viridis')
# Out:
# go
